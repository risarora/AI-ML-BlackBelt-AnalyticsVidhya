# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# !ls ./../../CV101/datasets/emergency_classification/images/1.*
# Out:
# ./../../CV101/datasets/emergency_classification/images/1.jpg

# %%
path="./../../CV101/datasets/emergency_classification/images/"
imageName = "1.jpg";
myimage=path+imageName

# %%
img = plt.imread(myimage)

# %%
img
# Out:
# array([[[30, 29, 24],
#         [21, 20, 15],
#         [19, 18, 13],
#         ...,
#         [17, 13, 10],
#         [16, 12,  9],
#         [15, 11,  8]],
#
#        [[26, 25, 20],
#         [19, 18, 13],
#         [17, 16, 11],
#         ...,
#         [16, 12,  9],
#         [14, 10,  7],
#         [11,  7,  4]],
#
#        [[23, 23, 15],
#         [17, 16, 11],
#         [16, 15, 10],
#         ...,
#         [13,  9,  6],
#         [13,  9,  6],
#         [13,  9,  6]],
#
#        ...,
#
#        [[70, 75, 78],
#         [69, 74, 77],
#         [70, 75, 78],
#         ...,
#         [39, 43, 46],
#         [37, 41, 44],
#         [34, 38, 41]],
#
#        [[68, 73, 76],
#         [68, 73, 76],
#         [69, 74, 77],
#         ...,
#         [37, 41, 44],
#         [37, 41, 44],
#         [37, 41, 44]],
#
#        [[73, 78, 81],
#         [73, 78, 81],
#         [75, 80, 83],
#         ...,
#         [30, 34, 37],
#         [33, 37, 40],
#         [37, 41, 44]]], dtype=uint8)

# %%
plt.imshow(img)
print(img.shape)
# Out:
# (224, 224, 3)

# %%
plt.imshow(img[:,:,0],cmap="Reds")

# %%
plt.imshow(img[:,:,1],cmap="Blues")

# %%
plt.imshow(img[:,:,2],cmap="Greens")

# %%
patch = img[125:175,150:200]
plt.imshow(patch)

# %%
from skimage.exposure import adjust_gamma
plt.imshow(adjust_gamma(img))

# %% [markdown]
# ### Load all the images i glob object and fetch an image randomly

# %%
from glob import glob

# %%
path = "./../../CV101/datasets/emergency_classification/images/"
images = glob(path+"*.jpg")

# %%
images[1:5]
# Out:
# ['./../../CV101/datasets/emergency_classification/images/823.jpg',
#  './../../CV101/datasets/emergency_classification/images/2100.jpg',
#  './../../CV101/datasets/emergency_classification/images/1409.jpg',
#  './../../CV101/datasets/emergency_classification/images/189.jpg']

# %%
rng = np.random.RandomState()

# %%
rng.choice(images)
# Out:
# './../../CV101/datasets/emergency_classification/images/114.jpg'

# %%
img_name = rng.choice(images)
img = plt.imread(img_name)
plt.imshow(img)
print(img_name)
# Out:
# ./../../CV101/datasets/emergency_classification/images/104.jpg

# %%
import pandas as pd

# %%
data = pd.read_csv("./../../CV101/datasets/emergency_classification/emergency_classification.csv")

# %%
data.head()
# Out:
#   image_names  emergency_or_not
# 0       0.jpg                 1
# 1       1.jpg                 1
# 2       2.jpg                 1
# 3       3.jpg                 1
# 4       4.jpg                 1

# %%
data['emergency_or_not'].value_counts()
# Out:
# 0    1361
# 1     991
# Name: emergency_or_not, dtype: int64

# %%
row_index = rng.choice(data.index)

# %%
path='./../../CV101/datasets/emergency_classification/images/'

img_name = data.iloc[row_index]['image_names']
img = plt.imread(path+img_name)
plt.imshow(img)
target = data.iloc[row_index]['emergency_or_not']

if (target == 1 ):
    print("Emergency")
else :
        print("Non Emergency")
# Out:
# Non Emergency
