# %%
import pandas as pd 
tweets = pd.read_csv("tweets.csv", encoding = "ISO-8859-1")
tweets.head()
# Out:
#    Unnamed: 0  X                                               text  \
# 0           1  1  RT @rssurjewala: Critical question: Was PayTM ...
# 1           2  2  RT @Hemant_80: Did you vote on #Demonetization...
# 2           3  3  RT @roshankar: Former FinSec, RBI Dy Governor,...
# 3           4  4  RT @ANI_news: Gurugram (Haryana): Post office ...
# 4           5  5  RT @satishacharya: Reddy Wedding! @mail_today ...
#
#    favorited  favoriteCount replyToSN              created  truncated  \
# 0      False              0       NaN  2016-11-23 18:40:30      False
# 1      False              0       NaN  2016-11-23 18:40:29      False
# 2      False              0       NaN  2016-11-23 18:40:03      False
# 3      False              0       NaN  2016-11-23 18:39:59      False
# 4      False              0       NaN  2016-11-23 18:39:39      False
#
#    replyToSID            id  replyToUID  \
# 0         NaN  8.014957e+17         NaN
# 1         NaN  8.014957e+17         NaN
# 2         NaN  8.014955e+17         NaN
# 3         NaN  8.014955e+17         NaN
# 4         NaN  8.014954e+17         NaN
#
#                                         statusSource       screenName  \
# 0  <a href="http://twitter.com/download/android" ...  HASHTAGFARZIWAL
# 1  <a href="http://twitter.com/download/android" ...   PRAMODKAUSHIK9
# 2  <a href="http://twitter.com/download/android" ...  rahulja13034944
# 3  <a href="http://twitter.com/download/android" ...        deeptiyvd
# 4  <a href="http://cpimharyana.com" rel="nofollow...        CPIMBadli
#
#    retweetCount  isRetweet  retweeted
# 0           331       True      False
# 1            66       True      False
# 2            12       True      False
# 3           338       True      False
# 4           120       True      False

# %%
tweets["text"].head()
# Out:
# 0    RT @rssurjewala: Critical question: Was PayTM ...
# 1    RT @Hemant_80: Did you vote on #Demonetization...
# 2    RT @roshankar: Former FinSec, RBI Dy Governor,...
# 3    RT @ANI_news: Gurugram (Haryana): Post office ...
# 4    RT @satishacharya: Reddy Wedding! @mail_today ...
# Name: text, dtype: object

# %%
import string 
from nltk.corpus import stopwords 
stopwords = stopwords.words("english")

def _clean(txt):
    txt = txt.lower()
    txt = "".join(x for x in txt if x not in string.punctuation)
    words = txt.split()
    words = [w for w in words if w not in stopwords]
    txt = " ".join(words)
    return txt

tweets["cleaned"] = tweets["text"].apply(lambda x : _clean(x))
tweets[["text", "cleaned"]]
# Out:
#                                                     text  \
# 0      RT @rssurjewala: Critical question: Was PayTM ...
# 1      RT @Hemant_80: Did you vote on #Demonetization...
# 2      RT @roshankar: Former FinSec, RBI Dy Governor,...
# 3      RT @ANI_news: Gurugram (Haryana): Post office ...
# 4      RT @satishacharya: Reddy Wedding! @mail_today ...
# 5      @DerekScissors1: Indias #demonetization: #Bla...
# 6      RT @gauravcsawant: Rs 40 lakh looted from a ba...
# 7      RT @Joydeep_911: Calling all Nationalists to j...
# 8      RT @sumitbhati2002: Many opposition leaders ar...
# 9      National reform now destroyed even the essence...
# 10     Many opposition leaders are with @narendramodi...
# 11     RT @Joydas: Question in Narendra Modi App wher...
# 12     @Jaggesh2 Bharat band on 28??<ed><U+00A0><U+00...
# 13     RT @Atheist_Krishna: The effect of #Demonetiza...
# 14     RT @sona2905: When I explained #Demonetization...
# 15     RT @Dipankar_cpiml: The Modi app on #DeMonetiz...
# 16     RT @roshankar: Former FinSec, RBI Dy Governor,...
# 17     RT @Atheist_Krishna: BEFORE and AFTER Gandhi j...
# 18     RT @pGurus1: #Demonetization The co-operative ...
# 19     RT @roshankar: Former FinSec, RBI Dy Governor,...
# 20     RT @Hemant_80: Did you vote on #Demonetization...
# 21     RT @roshankar: Former FinSec, RBI Dy Governor,...
# 22     RT @Atheist_Krishna: BEFORE and AFTER Gandhi j...
# 23     RT @MahikaInfra: @narendramodi\r\n@Swamy39\r\n...
# 24     RT @Hemant_80: Did you vote on #Demonetization...
# 25     RT @roshankar: Former FinSec, RBI Dy Governor,...
# 26     RT @kapil_kausik: #Doltiwal I mean #JaiChandKe...
# 27     RT @roshankar: Former FinSec, RBI Dy Governor,...
# 28     RT @kapil_kausik: #Doltiwal I mean #JaiChandKe...
# 29     RT @AAPVind: #Demonetization Is Disaster!  @na...
# ...                                                  ...
# 14910  RT @rahulroushan: Prohibition is Demonetizatio...
# 14911  RT @rahulroushan: Prohibition is Demonetizatio...
# 14912  RT @rahulroushan: Prohibition is Demonetizatio...
# 14913  RT @rahulroushan: Prohibition is Demonetizatio...
# 14914  RT @hindustanse: #Mind_it.....Arnab Goswami sl...
# 14915  RT @rahulroushan: Prohibition is Demonetizatio...
# 14916  As someone who is trying to break into interne...
# 14917  RT @bharat_builder: Lol. Demonetization has fi...
# 14918  RT @rahulroushan: Prohibition is Demonetizatio...
# 14919  RT @rahulroushan: Prohibition is Demonetizatio...
# 14920  RT @rahulroushan: Prohibition is Demonetizatio...
# 14921  RT @rahulroushan: Prohibition is Demonetizatio...
# 14922  RT @rahulroushan: Prohibition is Demonetizatio...
# 14923  RT @rahulroushan: Prohibition is Demonetizatio...
# 14924  RT @rahulroushan: Prohibition is Demonetizatio...
# 14925  @moneycontrolcom Who wrote this article? You g...
# 14926  RT @rahulroushan: Prohibition is Demonetizatio...
# 14927  RT @rahulroushan: Prohibition is Demonetizatio...
# 14928  RT @rahulroushan: Prohibition is Demonetizatio...
# 14929  RT @rahulroushan: Prohibition is Demonetizatio...
# 14930  RT @rahulroushan: Prohibition is Demonetizatio...
# 14931  RT @bharat_builder: Lol. Demonetization has fi...
# 14932  Can cash -- or the end of cash -- end poverty ...
# 14933  @thehill To The Hill. Shame on you for your an...
# 14934  RT @Vidyut: How India became Bill Gates' guine...
# 14935  RT @saxenavishakha: Ghost of demonetization re...
# 14936  N d modi fans-d true nationalists of the count...
# 14937  RT @bharat_builder: Lol. Demonetization has fi...
# 14938  RT @Stupidosaur: @Vidyut B team of BJP. CIA ba...
# 14939  @Vidyut B team of BJP. CIA baby. CCTV, EVM but...
#
#                                                  cleaned
# 0      rt rssurjewala critical question paytm informe...
# 1        rt hemant80 vote demonetization modi survey app
# 2      rt roshankar former finsec rbi dy governor cbd...
# 3      rt aninews gurugram haryana post office employ...
# 4      rt satishacharya reddy wedding mailtoday carto...
# 5      derekscissors1 indias demonetization blackmon...
# 6      rt gauravcsawant rs 40 lakh looted bank kishtw...
# 7      rt joydeep911 calling nationalists join walk c...
# 8      rt sumitbhati2002 many opposition leaders nare...
# 9      national reform destroyed even essence sagan i...
# 10     many opposition leaders narendramodi demonetiz...
# 11     rt joydas question narendra modi app pm taking...
# 12     jaggesh2 bharat band 28edu00a0u00bdedu00b8u008...
# 13     rt atheistkrishna effect demonetization httpst...
# 14     rt sona2905 explained demonetization tried put...
# 15     rt dipankarcpiml modi app demonetization prove...
# 16     rt roshankar former finsec rbi dy governor cbd...
# 17     rt atheistkrishna gandhi ji heard standing dem...
# 18     rt pgurus1 demonetization cooperative banking ...
# 19     rt roshankar former finsec rbi dy governor cbd...
# 20       rt hemant80 vote demonetization modi survey app
# 21     rt roshankar former finsec rbi dy governor cbd...
# 22     rt atheistkrishna gandhi ji heard standing dem...
# 23     rt mahikainfra narendramodi swamy39 success de...
# 24       rt hemant80 vote demonetization modi survey app
# 25     rt roshankar former finsec rbi dy governor cbd...
# 26     rt kapilkausik doltiwal mean jaichandkejriwal ...
# 27     rt roshankar former finsec rbi dy governor cbd...
# 28     rt kapilkausik doltiwal mean jaichandkejriwal ...
# 29             rt aapvind demonetization disaster naampk
# ...                                                  ...
# 14910  rt rahulroushan prohibition demonetization 20 ...
# 14911  rt rahulroushan prohibition demonetization 20 ...
# 14912  rt rahulroushan prohibition demonetization 20 ...
# 14913  rt rahulroushan prohibition demonetization 20 ...
# 14914  rt hindustanse minditarnab goswami slams patho...
# 14915  rt rahulroushan prohibition demonetization 20 ...
# 14916  someone trying break internet media whole yout...
# 14917  rt bharatbuilder lol demonetization fixed lot ...
# 14918  rt rahulroushan prohibition demonetization 20 ...
# 14919  rt rahulroushan prohibition demonetization 20 ...
# 14920  rt rahulroushan prohibition demonetization 20 ...
# 14921  rt rahulroushan prohibition demonetization 20 ...
# 14922  rt rahulroushan prohibition demonetization 20 ...
# 14923  rt rahulroushan prohibition demonetization 20 ...
# 14924  rt rahulroushan prohibition demonetization 20 ...
# 14925  moneycontrolcom wrote article get call taxmen ...
# 14926  rt rahulroushan prohibition demonetization 20 ...
# 14927  rt rahulroushan prohibition demonetization 20 ...
# 14928  rt rahulroushan prohibition demonetization 20 ...
# 14929  rt rahulroushan prohibition demonetization 20 ...
# 14930  rt rahulroushan prohibition demonetization 20 ...
# 14931  rt bharatbuilder lol demonetization fixed lot ...
# 14932  cash end cash end poverty india httpstcolffzzf...
# 14933  thehill hill shame antisemitic demonetization ...
# 14934  rt vidyut india became bill gates guinea pig c...
# 14935  rt saxenavishakha ghost demonetization returns...
# 14936  n modi fansd true nationalists country stil th...
# 14937  rt bharatbuilder lol demonetization fixed lot ...
# 14938  rt stupidosaur vidyut b team bjp cia baby cctv...
# 14939  vidyut b team bjp cia baby cctv evm vvpat supp...
#
# [14940 rows x 2 columns]

# %%
## Keyword Analysis 
from collections import Counter
complete_text = " ".join(tweets["text"])
clean_text = _clean(complete_text)
Counter(clean_text.split()).most_common(100)
# Out:
# [('demonetization', 13939),
#  ('rt', 11059),
#  ('india', 2766),
#  ('modi', 2759),
#  ('pm', 2729),
#  ('narendra', 1566),
#  ('rich', 1509),
#  ('find', 1422),
#  ('dear', 1411),
#  ('implement', 1399),
#  ('evanspiegel', 1389),
#  ('actually', 1374),
#  ('amp', 1302),
#  ('urautelaforever', 1273),
#  ('narendramodi', 1162),
#  ('people', 1092),
#  ('bank', 1029),
#  ('rs', 740),
#  ('impact', 701),
#  ('cash', 697),
#  ('lakh', 686),
#  ('support', 684),
#  ('terrorists', 658),
#  ('youtube', 642),
#  ('jampk', 638),
#  ('since', 596),
#  ('nation', 594),
#  ('thats', 581),
#  ('move', 553),
#  ('third', 552),
#  ('40', 550),
#  ('looted', 547),
#  ('incident', 547),
#  ('kishtwar', 544),
#  ('modibharosa', 543),
#  ('gauravcsawant', 541),
#  ('money', 512),
#  ('question', 507),
#  ('back', 499),
#  ('across', 453),
#  ('atms', 449),
#  ('like', 442),
#  ('says', 401),
#  ('due', 401),
#  ('supports', 393),
#  ('goes', 376),
#  ('paytm', 374),
#  ('drkumarvishwas', 358),
#  ('https', 354),
#  ('oscar', 353),
#  ('mru092du093eu0935u0941u0915', 353),
#  ('edu00a0u00bdedu00b8u00a9edu00a0u00bdedu00b8u00a5edu00a0u00bdedu00b8u00a2edu00a0u00bdedu00b8u00addemonetization',
#   353),
#  ('httpstcoobqrhlnsl6', 350),
#  ('app', 349),
#  ('good', 343),
#  ('whether', 343),
#  ('still', 340),
#  ('govt', 336),
#  ('modis', 328),
#  ('notes', 323),
#  ('full', 319),
#  ('bjp', 319),
#  ('httpst', 312),
#  ('poor', 308),
#  ('shortage', 305),
#  ('party', 304),
#  ('clearly', 301),
#  ('rssurjewala', 296),
#  ('critical', 296),
#  ('bypolls', 291),
#  ('informed', 290),
#  ('edict', 289),
#  ('effect', 289),
#  ('5forty3', 288),
#  ('first', 286),
#  ('fishy', 285),
#  ('requires', 284),
#  ('rahulroushan', 284),
#  ('politics', 282),
#  ('huge', 281),
#  ('cvoter', 280),
#  ('disclosure', 279),
#  ('man', 267),
#  ('black', 264),
#  ('\x92s', 263),
#  ('8086', 262),
#  ('nitishkumar', 261),
#  ('economy', 260),
#  ('putting', 258),
#  ('today', 254),
#  ('httpstcouodwxdpmmg', 254),
#  ('pmoindia', 250),
#  ('dont', 249),
#  ('su', 248),
#  ('running', 240),
#  ('survey', 239),
#  ('centerofright', 239),
#  ('watch', 235),
#  ('digital', 233),
#  ('new', 231)]

# %%
## Top Mentions 
mentions = [w for w in complete_text.split() if w.startswith("@")]
Counter(mentions).most_common(100)
# Out:
# [('@evanspiegel', 1306),
#  ('@URautelaForever:', 1273),
#  ('@narendramodi', 1109),
#  ('@gauravcsawant:', 541),
#  ('@ModiBharosa:', 539),
#  ('@DrKumarVishwas:', 350),
#  ('@5Forty3:', 285),
#  ('@rssurjewala:', 280),
#  ('@rahulroushan:', 280),
#  ('@PMOIndia', 237),
#  ('@centerofright:', 237),
#  ('@ShashiTharoor:', 210),
#  ('@DasShaktikanta', 195),
#  ('@steve_hanke:', 176),
#  ('@ashu3page:', 170),
#  ('@kanimozhi:', 152),
#  ('@AskAnshul:', 149),
#  ('@RoflGandhi_:', 147),
#  ('@YouTube', 145),
#  ('@Timcast:', 137),
#  ('@Atheist_Krishna:', 133),
#  ('@', 132),
#  ('@ArvindKejriwal', 130),
#  ('@Joydas:', 113),
#  ('@arunjaitley', 112),
#  ('@ippatel:', 110),
#  ('@jamewils:', 105),
#  ('@FinMinIndia', 104),
#  ('@Joydeep_911:', 102),
#  ('@attomeybharti:', 101),
#  ('@PIB_India:', 97),
#  ('@PiyushGoyalOffc:', 95),
#  ('@Memeghnad', 84),
#  ('@DrGPradhan:', 83),
#  ('@priyaakulkarni2:', 80),
#  ('@minimathur', 79),
#  ('@MIB_India:', 79),
#  ('@dna:', 76),
#  ('@Ra_THORe:', 75),
#  ('@pGurus1:', 74),
#  ('@_MiteshPatel:', 73),
#  ('@aaanupriyaaa:', 70),
#  ('@aartic02:', 69),
#  ('@NG_withINC:', 68),
#  ('@Hemant_80:', 62),
#  ('@jairajp:', 62),
#  ('@na', 59),
#  ('@harshkkapoor:', 58),
#  ('@anandkamal', 54),
#  ('@ShirishKunder:', 54),
#  ('@anilkohli54:', 52),
#  ('@DipendraDipzo:', 52),
#  ('@arvindsubraman', 51),
#  ('@mkatju:', 50),
#  ('@mahcongress:', 48),
#  ('@TarekFatah', 47),
#  ('@madskak:', 46),
#  ('@HumorMinistry:', 46),
#  ('@ShefVaidya:', 45),
#  ('@Dipankar_cpiml:', 44),
#  ('@AdityaNair20:', 44),
#  ('@PrasadAol', 44),
#  ('@rashminp', 44),
#  ('@DrShobha:', 43),
#  ('@barbarindian:', 43),
#  ('@Stupidosaur:', 42),
#  ('@RealHistoryPic:', 41),
#  ('@SecretaryMEITY:', 41),
#  ('@AnnieLowrey', 41),
#  ('@YSRCParty:', 40),
#  ('@P', 40),
#  ('@MinIT_Telangana:', 40),
#  ('@TheDarjChron:', 39),
#  ('@myvotetoday:', 37),
#  ('@OfficeOfRG', 37),
#  ('@RBI', 36),
#  ('@Nr_Shiralkar:', 36),
#  ('@ms_rana:', 34),
#  ('@LionelMedia:', 34),
#  ('@msisodia', 33),
#  ('@BajajAllianzLIC:', 33),
#  ('@MilanV:', 33),
#  ('@amazingatheist:', 33),
#  ('@Janamejayan:', 32),
#  ('@IndiaExplained', 32),
#  ('@ndtv', 30),
#  ('@hi_paresh:', 30),
#  ('@sanjayuv', 30),
#  ('@sardesairajdeep', 29),
#  ('@upma23', 29),
#  ('@bsindia:', 29),
#  ('@IncomeTaxIndia:', 29),
#  ('@MarkDice:', 29),
#  ('@Punitspeaks:', 28),
#  ('@jackerhack:', 28),
#  ('@UnS', 27),
#  ('@ncbn', 27),
#  ('@MinhazMerchant:', 27),
#  ('@internetfreedom', 27),
#  ('@YesIamSaffron:', 27)]

# %%
## Top HashTags
htags = [w for w in complete_text.split() if w.startswith("#")]
htags = [w for w in htags if "demo" not in w.lower()]
Counter(htags).most_common(100)
# Out:
# [('#India', 295),
#  ('#nitishkumar', 257),
#  ('#GLvMI', 145),
#  ('#CorruptionFreeIndia', 103),
#  ('#BlackMoney', 91),
#  ('#VijayMallya', 86),
#  ('#IndiaFightsCorruption', 79),
#  ('#Modi', 67),
#  ('#NoMoneyYaar', 53),
#  ('#BJP', 50),
#  ('#SonuNigam', 47),
#  ('#RatanTata', 44),
#  ('#Insights', 44),
#  ('#bulletin', 44),
#  ('#boycottsnapchat', 43),
#  ('#RBI', 42),
#  ('#LifeInsurance', 34),
#  ('#YouTubeIsDead', 30),
#  ('#NMApp', 29),
#  ('#MeraDeshBadalRaha', 28),
#  ("#India's", 27),
#  ('#PMModi', 25),
#  ('#NarendraModi', 25),
#  ('#news', 25),
#  ('#TrustBJP', 25),
#  ('#not', 23),
#  ('#CGDTalks', 23),
#  ('#Hitler', 20),
#  ('#Hilarious.', 20),
#  ('#lifehacks', 19),
#  ('#Doltiwal', 18),
#  ('#JaiChandKejriwal', 18),
#  ('#survey', 18),
#  ('#PM', 18),
#  ('#india', 18),
#  ('#ITVideo', 18),
#  ('#IndiaKaDil.', 17),
#  ('#', 17),
#  ('#NorthEast', 17),
#  ('#NoteNahiPMBadlo', 17),
#  ("#Modi's", 17),
#  ('#NetasCASHIn', 17),
#  ('#IncrementPremierLeague', 17),
#  ("#NarendraModi's", 16),
#  ('#Bitcoin', 16),
#  ('#WarOnCash', 16),
#  ('#payments', 16),
#  ('#Snapchat', 16),
#  ('#blackmoney', 15),
#  ('#MayawatiNextUPCM', 15),
#  ('#BSP', 15),
#  ('#YouTube', 15),
#  ('#summary:', 14),
#  ('#<U+0938><U+0902><U+0938><U+0926>_<U+092A><U+0941><U+0915><U+093E><U+0930><U+0947>_PM_<U+092A><U+094D><U+092F><U+093E><U+0930><U+0947>',
#   14),
#  ('#India\x92s', 14),
#  ('#queue', 13),
#  ('#Digital', 13),
#  ('#PuthanPanam', 13),
#  ('#Bypolls', 12),
#  ('#YSJagan', 12),
#  ('#Ysrcp', 12),
#  ('#NCBN', 12),
#  ('#Tdp', 12),
#  ('#janjankibaat', 12),
#  ('#Startup', 12),
#  ('#Delhi', 12),
#  ('#banks', 12),
#  ('#ModiFightsCorruption', 12),
#  ('#money', 12),
#  ('#CJIThakur', 11),
#  ('#SpicesNSecrets', 11),
#  ('#Waiting', 11),
#  ('#KejriPappuDidiTypes', 11),
#  ('#MannKiBaat', 11),
#  ('#Pakistan-#Separatist', 11),
#  ('#KashmirUnrest', 11),
#  ('#NarendraModii', 11),
#  ('#Parliament', 11),
#  ('#wintersession', 11),
#  ('#Kerala', 11),
#  ('#WithdrawUpto1000FromATM', 11),
#  ('#cashless', 11),
#  ('#lenders.', 11),
#  ('#fintech', 11),
#  ('#Washington', 11),
#  ('#VishalJanSabha', 10),
#  ('#ATM', 10),
#  ('#JanKiBaat', 10),
#  ('#currencyban', 10),
#  ('#Gui', 10),
#  ('#Bypolls:', 10),
#  ('#MamtaKejriXposed', 10),
#  ('#Aadhaar', 10),
#  ('#Censorship', 10),
#  ('#<U+0928><U+093E><U+092A><U+093E><U+0915>_<U+092A><U+0924><U+094D><U+0925><U+0930><U+092C><U+093E><U+091C>',
#   10),
#  ('#ACJLive', 10),
#  ('#GST', 9),
#  ('#cash', 9),
#  ('#Kriti', 9),
#  ('#ATMWithCash', 9)]

# %%
## Top URLs
htags = [w for w in complete_text.split() if w.startswith("http")]
htags = [w for w in htags if "demon" not in w.lower()]
Counter(htags).most_common(100)
# Out:
# [('https://t.co/ObQrhlNSL6', 350),
#  ('https://t.co/UodwXdPMmG', 254),
#  ('https://t', 252),
#  ('https://t.c', 187),
#  ('https:/', 162),
#  ('https://t.co/DGAI5cf05y', 120),
#  ('https://t.co/pYgK8Rmg7r', 114),
#  ('https://t.co/TDj2A6uO5u', 95),
#  ('https://t.co/9NheK63TPg', 91),
#  ('https://t.co/', 90),
#  ('http', 83),
#  ('https://t.co/heTEYUM0ch', 80),
#  ('https:', 76),
#  ('https://t.co/3TP2svF', 73),
#  ('https', 72),
#  ('https://t.co/E', 69),
#  ('https://t.', 60),
#  ('https://t.co/D85BiDMvFM', 47),
#  ('https://t.co/4RMD7Fpfaw', 45),
#  ('https://t.co/A8of7zh2f5', 44),
#  ('https://', 44),
#  ('https://t.co/fRTHY2Ltth', 41),
#  ('https://t.co/NVv7slCcpr', 41),
#  ('https://t.co/X2ME55oPks', 35),
#  ('https://t.co/0fMh3UMbVq', 32),
#  ('https://t.co/T1Agu6CH33', 29),
#  ('https://t.co/P6HkkDVa3b', 28),
#  ('https://g', 27),
#  ('https://t.co/ThzaV7r', 25),
#  ('https://t.co/ePVcU2T38F', 24),
#  ('https://t.co/EqbMve2T2F', 23),
#  ('https://t.co/PK9qO92K4N', 23),
#  ('https://t.co/Uc6jrbvUNE', 22),
#  ('https://t.co/rLr6wGdeaa', 22),
#  ('https://t.co/g', 21),
#  ('https://t.co/IeXuia3J0X', 20),
#  ('https://t.co/DRxxTEw9Zt', 20),
#  ('https://t.co', 19),
#  ('https://t.co/rng1gKiUgm', 19),
#  ('https://t.co/FRNAKe7', 19),
#  ('https://t.co/TAEYsN4yBF', 19),
#  ('https://t.co/LffZzfOKf8', 18),
#  ('https://t.co/62nqWWUgL1', 18),
#  ('https://t.co/rLPk6LPfv3', 17),
#  ('https://t.co/2IiIELPLlf', 16),
#  ('https://t.co/mMgPS675Uo', 16),
#  ('https://t.co/uCS21Uv5G8', 16),
#  ('https://t.co/RiJENeWX7y', 15),
#  ('https://t.co/ejlAIQOs2M', 15),
#  ('https://t.co/sIVo5YMhJp', 14),
#  ('https://t.co/BC1XHiZEdw', 13),
#  ('https://t.co/ggj', 13),
#  ('https://t.co/dbuSSTfWTo', 13),
#  ('https://t.co/g3simA6LEG', 13),
#  ('https://t.co/aCQ2FRRVmO', 13),
#  ('https://t.co/ZetKRqqClX', 12),
#  ('https://t.co/2lelg', 12),
#  ('https://t.co/9tjwqdwnkx', 12),
#  ('https://t.co/5bZP8StDk5', 12),
#  ('https://t.co/DY5Jw3X1Vr', 12),
#  ('https://t.co/LcglWWi1aX', 12),
#  ('https://t.co/jp', 12),
#  ('https://t.co/TyrIIEKZIU', 12),
#  ('https://t.co/N64rKmWBzs', 12),
#  ('https://t.co/9AwGwJAc5w', 11),
#  ('https://t.co/LEAj1IwvLy', 11),
#  ('https://t.co/qRw30XKE3z', 11),
#  ('https://t.co/nk92SWh6Ao', 11),
#  ('https://t.co/7kgZcIa6ee', 10),
#  ('https://t.co/OO0MptVdQT', 9),
#  ('https://t.co/Zbfo', 9),
#  ('https://t.co/kzfxekesh3\x96-how-big-ideas-are-ch', 9),
#  ('https://t.co/AqCn', 9),
#  ('https://t.co/yuVtv2Pwj8', 9),
#  ('https://t.co/Bffif3fbpm', 9),
#  ('https://t.co/lKvkYuCd1K', 8),
#  ('https://t.co/ExvHcctRGp', 8),
#  ('https://t.co/U8g4C7H', 8),
#  ('https://t.co/rFk0qMFchy', 8),
#  ('https://t.co/46khsz6lqt', 8),
#  ('https://t.co/CyyVY7FDcI', 8),
#  ('https://t.co/WDpsFankI1', 8),
#  ('https://t.co/rlRtkI3jyX', 8),
#  ('https://t.co/mRQo3KR6V6', 8),
#  ('https://t.co/4NtiL4fstd', 8),
#  ('https://t.co/AfYceebTBt', 8),
#  ('https://t.co/ZXHhMuwCEq', 8),
#  ('https://t.co/fWvEuH2De6', 7),
#  ('https://t.co/73EtE', 7),
#  ('https://t.co/0Gmlpksrpx', 7),
#  ('https://t.co/dQT9', 7),
#  ('https://t.co/gs7yLt0aws', 7),
#  ('https://t.co/UQeOf6ylMi', 7),
#  ('https://t.co/Azai2rBZV1', 7),
#  ('https://t.co/nfQISyHdC4', 7),
#  ('https://t.co/t6G8upEwTN', 7),
#  ('https://t.co/ZYLU2Al27f', 7),
#  ('https://t.co/blTu78XzQh', 7),
#  ('https://t.co/blTu79faHP', 7),
#  ('https://t.co/1dTjOt', 7)]

# %%
from nltk import ngrams

bigrams = ngrams(clean_text.split(), 2)
Counter(bigrams).most_common(100)
# Out:
# [(('narendra', 'modi'), 1565),
#  (('india', 'rich'), 1431),
#  (('pm', 'narendra'), 1424),
#  (('demonetization', 'find'), 1399),
#  (('implement', 'demonetization'), 1397),
#  (('rich', 'pm'), 1391),
#  (('modi', 'implement'), 1376),
#  (('evanspiegel', 'india'), 1371),
#  (('dear', 'evanspiegel'), 1366),
#  (('find', 'actually'), 1311),
#  (('rt', 'urautelaforever'), 1273),
#  (('urautelaforever', 'dear'), 1273),
#  (('actually', 'rt'), 1024),
#  (('pm', 'narendramodi'), 587),
#  (('since', 'demonetization'), 572),
#  (('demonetization', 'thats'), 546),
#  (('lakh', 'looted'), 544),
#  (('rs', '40'), 542),
#  (('40', 'lakh'), 542),
#  (('looted', 'bank'), 542),
#  (('bank', 'kishtwar'), 542),
#  (('kishtwar', 'jampk'), 542),
#  (('jampk', 'third'), 542),
#  (('third', 'incident'), 542),
#  (('incident', 'since'), 542),
#  (('thats', 'terrorists'), 542),
#  (('rt', 'modibharosa'), 542),
#  (('rt', 'gauravcsawant'), 541),
#  (('gauravcsawant', 'rs'), 541),
#  (('terrorists', 'rt'), 434),
#  (('demonetization', 'rt'), 429),
#  (('demonetization', 'move'), 383),
#  (('oscar', 'goes'), 353),
#  (('goes', 'mru092du093eu0935u0941u0915'), 353),
#  (('mru092du093eu0935u0941u0915',
#    'edu00a0u00bdedu00b8u00a9edu00a0u00bdedu00b8u00a5edu00a0u00bdedu00b8u00a2edu00a0u00bdedu00b8u00addemonetization'),
#   353),
#  (('drkumarvishwas', 'oscar'), 351),
#  (('rt', 'drkumarvishwas'), 350),
#  (('edu00a0u00bdedu00b8u00a9edu00a0u00bdedu00b8u00a5edu00a0u00bdedu00b8u00a2edu00a0u00bdedu00b8u00addemonetization',
#    'httpstcoobqrhlnsl6'),
#   350),
#  (('impact', 'demonetization'), 344),
#  (('narendramodi', 'demonetization'), 304),
#  (('supports', 'pm'), 301),
#  (('support', 'demonetization'), 295),
#  (('rt', 'rssurjewala'), 292),
#  (('rssurjewala', 'critical'), 289),
#  (('critical', 'question'), 289),
#  (('question', 'paytm'), 289),
#  (('paytm', 'informed'), 289),
#  (('informed', 'demonetization'), 289),
#  (('demonetization', 'edict'), 289),
#  (('edict', 'pm'), 288),
#  (('pm', 'clearly'), 288),
#  (('clearly', 'fishy'), 285),
#  (('rt', '5forty3'), 285),
#  (('fishy', 'requires'), 283),
#  (('requires', 'full'), 283),
#  (('rt', 'rahulroushan'), 280),
#  (('full', 'disclosure'), 279),
#  (('disclosure', 'amp'), 278),
#  (('httpstcoobqrhlnsl6', 'rt'), 277),
#  (('back', 'demonetization'), 276),
#  (('support', 'pm'), 269),
#  (('huge', 'support'), 263),
#  (('\x92s', 'demonetization'), 263),
#  (('move', 'across'), 263),
#  (('across', 'nation'), 263),
#  (('nation', '8086'), 262),
#  (('8086', 'people'), 261),
#  (('people', 'back'), 261),
#  (('nitishkumar', 'supports'), 258),
#  (('putting', 'nation'), 257),
#  (('nation', 'party'), 257),
#  (('party', 'politics'), 257),
#  (('politics', 'nitishkumar'), 257),
#  (('demonetization', 'cvoter'), 256),
#  (('modibharosa', 'putting'), 254),
#  (('demonetization', 'httpstcouodwxdpmmg'), 254),
#  (('narendramodi', '\x92s'), 252),
#  (('modibharosa', 'huge'), 249),
#  (('demonetization', 'people'), 247),
#  (('cvoter', 'su'), 246),
#  (('httpst', 'rt'), 239),
#  (('rt', 'centerofright'), 239),
#  (('due', 'demonetization'), 226),
#  (('amp', 'rt'), 222),
#  (('centerofright', 'demonetization'), 221),
#  (('rt', 'shashitharoor'), 211),
#  (('httpstcouodwxdpmmg', 'rt'), 204),
#  (('su', 'rt'), 202),
#  (('black', 'money'), 198),
#  (('demonetization', 'effect'), 197),
#  (('jan', 'dhan'), 195),
#  (('impact', 'india'), 193),
#  (('demonetization', 'modis'), 193),
#  (('dhan', 'ujjwala'), 190),
#  (('ujjwala', 'neem'), 190),
#  (('neem', 'coated'), 190),
#  (('coated', 'urea'), 190),
#  (('urea', 'emandis'), 190),
#  (('emandis', 'demonetization'), 190),
#  (('modis', 'impact'), 190)]

# %%
## NER 
import nltk
from nltk import word_tokenize, pos_tag 
from nltk.chunk import tree2conlltags

for text in tweets["text"]:
    entities = nltk.ne_chunk(pos_tag(word_tokenize(text))) 
    for chunk in entities:
        if hasattr(chunk, "label"):
            if "GPE" in (str(chunk)):
                print (chunk)
            if "ORGANIZATION" in (str(chunk)):
                print (chunk)
#     break
# Out:
# (ORGANIZATION PM/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION RBI/NNP Dy/NNP)
# (ORGANIZATION CBDT/NNP)
# (ORGANIZATION Haryana/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (GPE National/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Jaggesh2/NNP Bharat/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION RBI/NNP Dy/NNP)
# (ORGANIZATION CBDT/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (GPE Kerala/NNP)
# (ORGANIZATION Black/NNP Money/NNP)
# (ORGANIZATION RBI/NNP Dy/NNP)
# (ORGANIZATION CBDT/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION RBI/NNP Dy/NNP)
# (ORGANIZATION CBDT/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION RBI/NNP Dy/NNP)
# (ORGANIZATION CBDT/NNP)
# (ORGANIZATION JaiChandKejriwal/NNP)
# (ORGANIZATION USELESS/NNP)
# (ORGANIZATION RBI/NNP Dy/NNP)
# (ORGANIZATION CBDT/NNP)
# (ORGANIZATION JaiChandKejriwal/NNP)
# (ORGANIZATION USELESS/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION NarendraModi/NNP)
# (ORGANIZATION DonMu/NNP)
# (ORGANIZATION Communal/NNP)
# (ORGANIZATION JaiChandKejriwal/NNP)
# (ORGANIZATION USELESS/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION BAU/NNP Operations/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Amex/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION RBI/NNP Dy/NNP)
# (ORGANIZATION CBDT/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (ORGANIZATION ModiSarkar/NNP)
# (ORGANIZATION GroundZero/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (ORGANIZATION Communal/NNP)
# (ORGANIZATION JaiChandKejriwal/NNP)
# (ORGANIZATION USELESS/NNP)
# (ORGANIZATION MinhazMerchant/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (GPE Indore/NNP)
# (GPE West/NNP)
# (GPE Kerala/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION MUDRA/NNP)
# (GPE Modi/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION IIP/NNP)
# (ORGANIZATION Great/NNP)
# (ORGANIZATION Congress/NNP)
# (GPE Indian/JJ)
# (ORGANIZATION NarendraModi/NNP)
# (ORGANIZATION RBI/NNP Dy/NNP)
# (ORGANIZATION CBDT/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Modi/NNP)
# (GPE India/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION DonMu/NNP)
# (ORGANIZATION SOS/NNP)
# (GPE Modi/NNP)
# (GPE Gujarat/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION JaiChandKejriwal/NNP)
# (ORGANIZATION USELESS/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (ORGANIZATION SBI/NN)
# (GPE India/NNP)
# (ORGANIZATION MUDRA/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (ORGANIZATION BogusPoll/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION DonMu/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION JaiChandKejriwal/NNP)
# (ORGANIZATION USELESS/NNP)
# (ORGANIZATION DonMu/NNP)
# (ORGANIZATION DonMu/NNP)
# (ORGANIZATION JaiChandKejriwal/NNP)
# (ORGANIZATION USELESS/NNP)
# (ORGANIZATION DonMu/NNP)
# (GPE Modi/NNP)
# (GPE Modi/NNP)
# (GPE Aam/NNP)
# (ORGANIZATION SBI/NNP)
# (GPE Teacher/NN)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (ORGANIZATION ICIC/NNP)
# (ORGANIZATION CEO/NNP)
# (GPE Hinterland/NNP)
# (ORGANIZATION IndiaKaDil/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION DEA/NNP)
# (ORGANIZATION DeshhBhakt/NNP)
# (ORGANIZATION GPS/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION GDP/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION RBI/NNP Dy/NNP)
# (ORGANIZATION CBDT/NNP)
# (ORGANIZATION BlackMoney/NNP)
# (ORGANIZATION PM/NNP Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Opposition/NNP)
# (ORGANIZATION Parliame/NN)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION RBI/NNP Dy/NNP)
# (ORGANIZATION CBDT/NNP)
# (ORGANIZATION RTGS/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (ORGANIZATION RBI/NNP Dy/NNP)
# (ORGANIZATION CBDT/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION RBI/NNP Dy/NNP)
# (ORGANIZATION CBDT/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (ORGANIZATION Ultimate/NNP Weapon/NNP)
# (GPE Black/NNP)
# (ORGANIZATION Opposition/NNP)
# (ORGANIZATION Parliame/NN)
# (GPE Monumental/JJ)
# (GPE Kolkata/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION ICIC/NNP)
# (ORGANIZATION CEO/NNP)
# (ORGANIZATION BBC/NNP)
# (ORGANIZATION NDTV/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION NarendraModi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (ORGANIZATION Housewife/NNP)
# (GPE India/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION BlackMoney/NNP)
# (ORGANIZATION AmitShah/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION MamtaOfficiaI/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Demonetization/NNP)
# (GPE India/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE India/NNP)
# (ORGANIZATION Brownie/NNP Points/NNPS)
# (GPE Indian/JJ)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (GPE Modi/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION Haryana/NNP)
# (GPE Modi/NNP)
# (GPE Modi/NNP)
# (GPE Modi/NNP)
# (GPE India/NNP)
# (ORGANIZATION Brownie/NNP Points/NNPS)
# (GPE Indian/JJ)
# (ORGANIZATION PM/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION YRDeshmukh/NNP Yes/NNP)
# (ORGANIZATION realDonaldTrump/NN)
# (ORGANIZATION VishalJanSabha/NNP)
# (ORGANIZATION KhulkeDulke/NNP)
# (ORGANIZATION Parliament/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION TMC/NNP)
# (ORGANIZATION PMModi/NNP)
# (ORGANIZATION NotProCongress/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION JaiChandKejriwal/NNP)
# (ORGANIZATION USELESS/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION RajanAnandan/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION JaiChandKejriwal/NNP)
# (ORGANIZATION USELESS/NNP)
# (GPE Bhopal/NNP)
# (ORGANIZATION ATMs/NNP)
# (ORGANIZATION DeMonetization/NN)
# (ORGANIZATION ArvindKejriwal/NNP)
# (ORGANIZATION TimesNow/NNP)
# (GPE World/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION Demonetization/NNP)
# (GPE India/NNP)
# (GPE Kishtwar/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION JaiChandKejriwal/NNP)
# (ORGANIZATION USELESS/NNP)
# (ORGANIZATION NarendraModi/NNP)
# (ORGANIZATION Oscar/NNP)
# (GPE Amazing/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (GPE Kishtwar/NNP)
# (GPE Indian/JJ)
# (GPE India/NNP)
# (GPE SouthAsia/NNP)
# (GPE Indian/JJ)
# (GPE India/NNP)
# (GPE SouthAsia/NNP)
# (GPE Indian/JJ)
# (GPE India/NNP)
# (GPE SouthAsia/NNP)
# (ORGANIZATION Creativity/NNP)
# (GPE Modi/NNP)
# (GPE Acid/NNP)
# (GPE Indian/JJ)
# (GPE India/NNP)
# (GPE SouthAsia/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION JaiChandKejriwal/NNP)
# (ORGANIZATION USELESS/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Indian/JJ)
# (ORGANIZATION BJP/NNP)
# (ORGANIZATION Demonetization/NN)
# (ORGANIZATION CashRush/NNP)
# (ORGANIZATION BlackMoney/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION MLA/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (GPE India/NNP)
# (ORGANIZATION JaiChandKejriwal/NNP)
# (ORGANIZATION USELESS/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION ArvindKejriwal/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION JaiChandKejriwal/NNP)
# (ORGANIZATION USELESS/NNP)
# (ORGANIZATION Real/NNP Estate/NNP)
# (GPE Banks/NNP)
# (ORGANIZATION SBI/NNP)
# (ORGANIZATION APP/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION JaiChandKejriwal/NNP)
# (ORGANIZATION USELESS/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (ORGANIZATION IndiaFightsCorruption/NNP Immense/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION JaiChandKejriwal/NNP)
# (ORGANIZATION USELESS/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION Oscar/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION DemonetizationMythsBusted/NNP)
# (ORGANIZATION JaiChandKejriwal/NNP)
# (ORGANIZATION USELESS/NNP)
# (ORGANIZATION JaiChandKejriwal/NNP)
# (ORGANIZATION USELESS/NNP)
# (ORGANIZATION SriSri/NNP Ravi/NNP Shankar/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION JaiChandKejriwal/NNP)
# (ORGANIZATION USELESS/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION Parliament/NNP)
# (GPE Heard/NNP)
# (ORGANIZATION ATM/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION Opposition/NNP)
# (ORGANIZATION Participate/NNP)
# (ORGANIZATION DNA/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION NarendraModi/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Kishtwar/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION APP/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION OfficeOfRG/NNP)
# (ORGANIZATION NetaVilla/NN)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION Parliament/NNP)
# (ORGANIZATION Congress/NNP)
# (GPE Maha/NNP)
# (GPE Mobile/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION Oscar/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION DEA/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION SitaramYechury/NNP Continue/NNP)
# (GPE Bengal/NNP)
# (GPE Modi/NNP)
# (GPE Delete/NNP)
# (ORGANIZATION BogusPoll/NNP)
# (ORGANIZATION Demonetization/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION ATMs/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION AeDilHaiMushkil/NNP)
# (GPE Modi/NNP)
# (GPE Surat/NNP)
# (ORGANIZATION AcheDin/NNP)
# (GPE Indian/JJ)
# (GPE India/NNP)
# (ORGANIZATION PM/NNP Modi/NNP)
# (GPE Massive/JJ)
# (ORGANIZATION Whatsapp/NNP)
# (GPE Facebook/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION GhulamNabiAzad/NNP)
# (ORGANIZATION Oscar/NNP)
# (ORGANIZATION INCIndia/NNP)
# (ORGANIZATION UPA/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION IAmWithModi/NNP)
# (GPE India/NNP)
# (ORGANIZATION MarcoWerman/NNP)
# (ORGANIZATION Bank/NNP)
# (ORGANIZATION Bank/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (GPE Parlmnt/NNP)
# (ORGANIZATION IAmWithModi/NNP)
# (ORGANIZATION Creativity/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION Bank/NNP)
# (GPE Modi/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION Opposition/NNP)
# (ORGANIZATION Parliame/NN)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION Opposition/NNP)
# (ORGANIZATION Parliame/NN)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION Communist/NNP Party/NNP)
# (GPE India/NNP)
# (ORGANIZATION Supreme/NNP Court/NNP)
# (GPE India/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Modi/NNP)
# (GPE India/NNP)
# (ORGANIZATION EconomicsBehind/NNP Economics/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (ORGANIZATION NoteBandi/NNP)
# (ORGANIZATION Opposition/NNP)
# (ORGANIZATION Parliame/NN)
# (ORGANIZATION RakhiSawant/NNP Support/NNP)
# (ORGANIZATION PMModi/NNP)
# (ORGANIZATION Rs500andRs1000/NNP)
# (GPE India/NNP)
# (ORGANIZATION MarcoWerman/NNP)
# (ORGANIZATION MUDRA/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (GPE India/NNP)
# (ORGANIZATION ofIndia/NN)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION NarendraModi/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION Opposition/NNP)
# (ORGANIZATION Parliame/NN)
# (GPE Modi/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION Opposition/NNP)
# (ORGANIZATION Parliame/NN)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (ORGANIZATION APP/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION Real/JJ Currency/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION BJP/NNP Parliamenta/NNP)
# (ORGANIZATION RBI/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION IndiaFightsCorruption/NNP Immense/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION NarendraModi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Watch/NN)
# (ORGANIZATION AeDilHaiMushkil/NNP)
# (ORGANIZATION Opposition/NNP)
# (ORGANIZATION Parliame/NN)
# (GPE Modi/NNP)
# (GPE Gadgets360/NN)
# (ORGANIZATION NarendraModi/NNP)
# (GPE Modi/NNP)
# (GPE Modi/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE India/NNP)
# (ORGANIZATION Economic/NNP Affairs/NNPS)
# (ORGANIZATION GOI/NNP)
# (ORGANIZATION MM/NNP Kutty/NNP)
# (ORGANIZATION CM/NNP Khandu/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION NarendraModi/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION AeDilHaiMushkil/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION MeraDeshBadalRaha/NNP)
# (ORGANIZATION ArshadWarsi/NNP)
# (ORGANIZATION BlackMoney/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (GPE Survey/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION NarendraModi/NNP)
# (ORGANIZATION BIBI/NNP)
# (ORGANIZATION NarendraModi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION RatanTata/NNP)
# (ORGANIZATION PM/NNP Narendra/NNP Modi/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION NarendraModi/NNP)
# (ORGANIZATION LowerEMI/NNP)
# (ORGANIZATION HappyHomes/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (GPE Modi/NNP)
# (GPE Gadgets360/NN)
# (ORGANIZATION NarendraModi/NNP)
# (ORGANIZATION NarendraModi/NNP)
# (GPE Ambani/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION NarendraModi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (GPE India/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION Bank/NNP)
# (ORGANIZATION RBI/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION DeMonetization/NN)
# (ORGANIZATION SitaramYechury/NNP Continue/NNP)
# (GPE Bengal/NNP)
# (GPE Total/JJ)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION CJIThakur/NNP)
# (ORGANIZATION DeMonetization/NNP Qs/NNP)
# (ORGANIZATION SpicesNSecrets/NNP)
# (GPE Indian/JJ)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION SrBachchan/NNP)
# (ORGANIZATION JayaBachchan/NNP)
# (ORGANIZATION DeMonetisation/NN)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION PMModi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION BlackMoney/NNP)
# (ORGANIZATION BJP/NNP)
# (ORGANIZATION CJIThakur/NNP)
# (ORGANIZATION DeMonetization/NNP Qs/NNP)
# (ORGANIZATION SpicesNSecrets/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION MamataOfficial/NNP)
# (GPE Bengal/NNP)
# (ORGANIZATION NDTV/NN)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (GPE Superb/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION GST/NNP Council/NNP)
# (GPE Pakistan/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Real/JJ Currency/NNP)
# (GPE India/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION NaMo/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Bank/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AntiModi/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION HPCL/NNP Bangalore/NNP)
# (ORGANIZATION APP/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION Oscar/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION AFTER/NNP Gandhi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (GPE Indian/JJ)
# (ORGANIZATION Gold/NNP)
# (GPE Indian/JJ)
# (GPE Modi/NNP)
# (ORGANIZATION PM/NNP Modi/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION YSRCP/NN Chief/NNP)
# (ORGANIZATION YSJagan/NNP)
# (ORGANIZATION NCBN/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Mmbi/NNP)
# (ORGANIZATION SBI/NNP Mahul/NNP Rd/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION DeMonetisation/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Modi/NNP)
# (GPE Indians/NNPS)
# (GPE Indians/NNPS)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (ORGANIZATION COMMON/NNP)
# (GPE D/NNP)
# (GPE Long/NNP)
# (ORGANIZATION Country/NNP)
# (ORGANIZATION NPA/NNP)
# (ORGANIZATION APP/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION PM/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (ORGANIZATION DeMonetisation/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Indore/NN)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION DEMONETISATION/NNP)
# (ORGANIZATION DEMONETIZATION/NNP)
# (ORGANIZATION DEMONETISATION/NNP)
# (ORGANIZATION DEMONETIZATION/NNP)
# (ORGANIZATION WhatsTheDealModiJi/NNP)
# (ORGANIZATION MediaCooks/NNP)
# (ORGANIZATION APP/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION MVenkaiahNaidu/NNP)
# (GPE Indian/JJ)
# (ORGANIZATION Congress/NNP)
# (GPE Kishtwar/NNP)
# (GPE Modi/NNP)
# (GPE Indian/JJ)
# (ORGANIZATION DEA/NNP)
# (GPE App/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION OMO/NNP)
# (ORGANIZATION FII/NNP)
# (GPE Crore/NNP)
# (GPE Please/NNP)
# (ORGANIZATION Good/JJ News/NN)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Glad/NNP)
# (ORGANIZATION NoteBan/NNP)
# (GPE Team/NN)
# (ORGANIZATION DEA/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION Demonetization/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION HPCL/NNP Bangalore/NNP)
# (GPE New/NNP Delhi/NNP)
# (GPE New/NNP Delhi/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (ORGANIZATION BJP/NNP)
# (GPE New/NNP)
# (GPE Modi/NNP)
# (GPE New/NNP)
# (GPE Modi/NNP)
# (GPE Indians/NNS)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Demons/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (GPE Cash/NNP Crunch/NNP)
# (ORGANIZATION RBI/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (GPE Modi/NNP)
# (GPE Bengal/NNP)
# (ORGANIZATION NDTV/NN)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION DemonetizationNoEffect/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (GPE Kishtwar/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION SBI/NN)
# (ORGANIZATION BJP/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION MUDRA/NNP)
# (ORGANIZATION TOI/NNP)
# (ORGANIZATION APP/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION ATM/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (GPE Sir/NNP)
# (GPE India/NNP)
# (GPE Modi/NNP)
# (GPE Crore/NNP)
# (ORGANIZATION PUBLIC/NNP)
# (ORGANIZATION RESPONSE/NNP)
# (ORGANIZATION BLACKMONEY/NNP)
# (ORGANIZATION APP/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION DeMonetization/NN)
# (GPE Modi/NNP)
# (ORGANIZATION HPCL/NNP)
# (ORGANIZATION Chennai/NNP)
# (ORGANIZATION Digital/NNP Identity/NNP Tags/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION IndiaFightsCorruption/NNP Immense/NNP)
# (GPE Rajasthan/NNP)
# (GPE Modi/NNP)
# (GPE Modi/NNP)
# (GPE Hinterland/NNP)
# (ORGANIZATION IndiaKaDil/NNP)
# (GPE India/NNP)
# (GPE West/NNP)
# (GPE Kerala/NNP)
# (ORGANIZATION MUDRA/NNP)
# (ORGANIZATION BJP/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION MUDRA/NNP)
# (ORGANIZATION APP/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION PMOpinionPoll/NNP Modi/NNP)
# (ORGANIZATION APP/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION TMC/NNP)
# (GPE WB/NNP)
# (ORGANIZATION DeMonetization/NN)
# (ORGANIZATION Supreme/NNP Court/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION BBC/NNP)
# (ORGANIZATION AAP/NNP)
# (ORGANIZATION Favorite/NNP)
# (GPE Modi/NNP)
# (GPE Modi/NNP)
# (GPE Modi/NNP)
# (GPE Modi/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION APP/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION SitaramYechury/NNP Continue/NNP)
# (GPE Bengal/NNP)
# (ORGANIZATION Oscar/NNP)
# (GPE India/NNP)
# (ORGANIZATION NoCash/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION ATMs/NNP)
# (ORGANIZATION Corruption/NNP)
# (ORGANIZATION PM/NNP App/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION PM/NNP)
# (GPE Modi/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION DeMonetization/NN)
# (GPE India/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION APP/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Modi/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION Pak/NNP)
# (GPE India/NNP)
# (GPE Kishtwar/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Kishtwar/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION BJP/NNP)
# (ORGANIZATION Success/NNP)
# (ORGANIZATION MamataOfficial/NNP)
# (GPE India/NNP)
# (GPE Kishtwar/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION RBI/NNP)
# (ORGANIZATION Corruption/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION DeMonetization/NN)
# (ORGANIZATION APP/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION ATMs/NNP)
# (ORGANIZATION APP/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION APP/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION STDs/NNP)
# (ORGANIZATION ATMs/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION ATMs/NNP)
# (ORGANIZATION ATM/NNP)
# (ORGANIZATION ATMs/NNP)
# (GPE Indirect/JJ)
# (ORGANIZATION APP/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION APP/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Kishtwar/NNP)
# (GPE Ts/NNP)
# (ORGANIZATION APP/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION DEA/NNP)
# (GPE Gujarat/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION NarendraModi/NNP)
# (ORGANIZATION APP/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION DeMonetization/NN)
# (ORGANIZATION SitaramYechury/NNP Continue/NNP)
# (GPE Bengal/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION TMC/NNP)
# (GPE WB/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION TMC/NNP)
# (GPE WB/NNP)
# (ORGANIZATION DeMonetisation/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION DeMonetization/NN)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION MUDRA/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (ORGANIZATION BlackMoney/NNP)
# (ORGANIZATION PM/NNP)
# (GPE Kishtwar/NNP)
# (GPE India/NNP)
# (ORGANIZATION Cash/NNP Crunch/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (GPE India/NNP)
# (ORGANIZATION DeshKiBaat/NNP Debate/NNP Panelist/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION DeMonetization/NN)
# (ORGANIZATION Mental/NNP Bankruptcy/NNP)
# (GPE Parliament/NNP)
# (GPE Indian/JJ)
# (GPE Child/NNP)
# (ORGANIZATION DeMonetization/NN)
# (ORGANIZATION Corruption/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION AeDilHaiMushkil/NNP)
# (ORGANIZATION iSupportModi/JJ)
# (GPE Gujarat/NNP)
# (ORGANIZATION Mental/NNP Bankruptcy/NNP)
# (GPE Parliament/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION Mental/NNP Bankruptcy/NNP)
# (GPE Parliament/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION PM/NNP Modi/NNP)
# (ORGANIZATION RakhiSawant/NNP Support/NNP)
# (ORGANIZATION PMModi/NNP)
# (ORGANIZATION Rs500andRs1000/NNP)
# (ORGANIZATION MUDRA/NNP)
# (ORGANIZATION MODIG/NNP)
# (GPE Trump/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION Mental/NNP Bankruptcy/NNP)
# (GPE Parliament/NNP)
# (ORGANIZATION Worthless/NNP Unpaid/NNP)
# (GPE Long/NNP)
# (GPE Indian/NNP)
# (ORGANIZATION GDP/NNP)
# (ORGANIZATION BWBusinessworld/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION Round/NNP Table/NNP)
# (GPE Long/NNP)
# (ORGANIZATION SocialMedia/NNP)
# (GPE India/NNP)
# (ORGANIZATION IRRESPONSIBLE/NNP Mamatha/NNP Banerjee/NNP)
# (ORGANIZATION BHARATH/NNP)
# (ORGANIZATION Mental/NNP Bankruptcy/NNP)
# (GPE Parliament/NNP)
# (ORGANIZATION Favorite/NNP)
# (ORGANIZATION BlackMoney/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION TMC/NNP)
# (GPE WB/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION PM/NNP)
# (GPE News24/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (GPE India/NNP)
# (ORGANIZATION PayTM/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (GPE Kishtwar/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Congress/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Worthless/NNP Unpaid/NNP)
# (GPE Atlast/NN)
# (ORGANIZATION PMOIndia/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION BlackMoney/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION Cash/NNP Crunch/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE India/NNP)
# (GPE America/NNP)
# (ORGANIZATION OPPOSITE/NNP)
# (ORGANIZATION PARTY/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION Corruption/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (GPE Think/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION MUDRA/NNP)
# (ORGANIZATION KARMA/NNP)
# (ORGANIZATION BlackMoney/NNP)
# (ORGANIZATION NoRollBackOfDeMonetization/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (ORGANIZATION Blackmoney/NNP)
# (ORGANIZATION Corruption/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Commitment/NNP)
# (GPE Blackmon/NNP)
# (ORGANIZATION CREDAI/NNP)
# (ORGANIZATION ArvindKejriwal/NNP)
# (ORGANIZATION BlackMoney/NNP)
# (ORGANIZATION KejriPappuDidiTypes/NNP)
# (ORGANIZATION MamataOfficial/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION Army/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION LOT/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Rajya/NNP)
# (ORGANIZATION CJIThakur/NNP)
# (ORGANIZATION DeMonetization/NNP Qs/NNP)
# (ORGANIZATION SpicesNSecrets/NNP)
# (ORGANIZATION ShashiTharoor/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION SupremeCourt/NNP)
# (ORGANIZATION MUDRA/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION CJIThakur/NNP)
# (ORGANIZATION DeMonetization/NNP Qs/NNP)
# (ORGANIZATION SpicesNSecrets/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (ORGANIZATION MUDRA/NNP)
# (ORGANIZATION ArvindKejriwal/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION PMOIndia/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION IEC2016/NNP)
# (ORGANIZATION WeThePeople/NNP)
# (ORGANIZATION PEACEFULLY/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION TMC/NNP)
# (GPE WB/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION Corruption/NNP)
# (GPE Bandh/NNP)
# (ORGANIZATION Bandh/NNP)
# (GPE Kishtwar/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION MUDRA/NNP)
# (ORGANIZATION BlackMoney/NNP)
# (ORGANIZATION ATM/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION PMModi/NNP Take/NNP Part/NNP)
# (GPE Survey/NNP)
# (ORGANIZATION NMApp/NNP)
# (ORGANIZATION Part/NNP)
# (ORGANIZATION Nation/NNP)
# (ORGANIZATION PMModi/NNP Take/NNP Part/NNP)
# (GPE Survey/NNP)
# (ORGANIZATION NMApp/NNP)
# (ORGANIZATION Part/NNP)
# (ORGANIZATION Nation/NNP)
# (GPE Naxalites/NNP)
# (GPE Mafias/NNP)
# (ORGANIZATION ISI/NNP Agents/NNP)
# (ORGANIZATION DALAL/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION TOI/NNP)
# (ORGANIZATION FinTech/NNP)
# (ORGANIZATION Congress/NNP)
# (ORGANIZATION CorruptionCle/NNP)
# (GPE India/NNP)
# (ORGANIZATION Gives/NNP)
# (ORGANIZATION Modi/NNP)
# (ORGANIZATION DeMonetization/NN)
# (GPE Kishtwar/NNP)
# (ORGANIZATION Real/NNP Estate/NNP)
# (GPE Banks/NNP)
# (ORGANIZATION SBI/NN)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION PMModi/NNP Take/NNP Part/NNP)
# (GPE Survey/NNP)
# (ORGANIZATION NMApp/NNP)
# (ORGANIZATION Part/NNP)
# (ORGANIZATION Nation/NNP)
# (ORGANIZATION MUDRA/NNP)
# (ORGANIZATION DeshKiBaat/NNP Debate/NNP Panelist/NNP)
# (ORGANIZATION DeshKiBaat/NNP Debate/NNP Panelist/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Kishtwar/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION MinisterMenu/NNP)
# (ORGANIZATION MamataOfficial/NNP)
# (GPE India/NNP)
# (ORGANIZATION KnowMore/NNP)
# (ORGANIZATION NewsX/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION MUDRA/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION TOI/NNP)
# (ORGANIZATION PTI_News/NNP)
# (ORGANIZATION NOTEBADI/NNP)
# (GPE India/NNP)
# (ORGANIZATION MUDRA/NNP)
# (ORGANIZATION MamataOfficial/NNP)
# (GPE India/NNP)
# (ORGANIZATION MamataOfficial/NNP)
# (GPE India/NNP)
# (GPE India/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION MamataOfficial/NNP)
# (GPE India/NNP)
# (ORGANIZATION Cash/NNP Crunch/NNP)
# (GPE India/NNP)
# (GPE India/NNP)
# (ORGANIZATION MamataOfficial/NNP)
# (GPE India/NNP)
# (ORGANIZATION Cash/NNP Crunch/NNP)
# (ORGANIZATION Aadmi/NNP)
# (GPE India/NNP)
# (ORGANIZATION AK/NNP Pappu/NNP)
# (GPE India/NNP)
# (ORGANIZATION AK/NNP Pappu/NNP)
# (ORGANIZATION MUDRA/NNP)
# (GPE India/NNP)
# (ORGANIZATION AK/NNP Pappu/NNP)
# (GPE India/NNP)
# (ORGANIZATION LowerEMI/NNP)
# (ORGANIZATION HappyHomes/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION TMC/NNP)
# (GPE WB/NNP)
# (GPE Indians/NNPS)
# (ORGANIZATION MUDRA/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION RBI/NNP)
# (ORGANIZATION Banking/NNP License/NNP)
# (GPE Hinterland/NNP)
# (ORGANIZATION IndiaKaDil/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Target/NNP)
# (ORGANIZATION JanKiBaat/NNP)
# (ORGANIZATION DEMONETIZATION/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (ORGANIZATION MUDRA/NNP)
# (ORGANIZATION Ultimate/NNP Weapon/NNP)
# (GPE Black/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION Bank/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION Ultimate/NNP Weapon/NNP)
# (GPE Black/NNP)
# (ORGANIZATION AmitShah/NNP Akali/NNP Dal/NNP)
# (ORGANIZATION BJP/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (ORGANIZATION MUDRA/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (GPE Indian/JJ)
# (ORGANIZATION PM/NNP)
# (GPE Bribery/NNP)
# (ORGANIZATION BharatBandh/NNP)
# (ORGANIZATION AeDilHaiMushkil/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION MUDRA/NNP)
# (ORGANIZATION NREGA/NNP)
# (ORGANIZATION ICIC/NNP)
# (ORGANIZATION CEO/NNP)
# (GPE Left/NNP)
# (ORGANIZATION JanKiBaat/NNP)
# (ORGANIZATION DEMONETIZATION/NNP)
# (ORGANIZATION JanKiBaat/NNP)
# (ORGANIZATION DEMONETIZATION/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION PMModi/NNP Take/NNP Part/NNP)
# (GPE Survey/NNP)
# (ORGANIZATION NMApp/NNP)
# (ORGANIZATION Part/NNP)
# (ORGANIZATION Nation/NNP)
# (ORGANIZATION MUDRA/NNP)
# (GPE Irony/NN)
# (ORGANIZATION NREGA/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Corruption/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION Opposition/NNP)
# (ORGANIZATION Parliame/NN)
# (ORGANIZATION MUDRA/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION MUDRA/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION NIPFP/NNP)
# (GPE Hinterland/NNP)
# (ORGANIZATION IndiaKaDil/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION LOT/NNP)
# (ORGANIZATION ATMs/NNP)
# (ORGANIZATION SandA/NN)
# (ORGANIZATION MUDRA/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION JanKiBaat/NNP)
# (ORGANIZATION DEMONETIZATION/NNP)
# (ORGANIZATION PM/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION Jaya/NNP Bachchan/NNP)
# (ORGANIZATION AAP/NNP)
# (ORGANIZATION TMC/NNP)
# (ORGANIZATION Jantar/NNP Mantar/NNP)
# (GPE Kishtwar/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION BJP/NNP)
# (GPE Hinterland/NNP)
# (ORGANIZATION IndiaKaDil/NNP)
# (ORGANIZATION ATMs/NNP)
# (ORGANIZATION SandA/NN)
# (ORGANIZATION PM/NNP)
# (GPE India/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Indians/NNPS)
# (ORGANIZATION BREAKING/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (ORGANIZATION CJIThakur/NNP)
# (ORGANIZATION DeMonetization/NNP Qs/NNP)
# (ORGANIZATION SpicesNSecrets/NNP)
# (ORGANIZATION CREDAI/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION CJIThakur/NNP)
# (ORGANIZATION DeMonetization/NNP Qs/NNP)
# (ORGANIZATION SpicesNSecrets/NNP)
# (ORGANIZATION AeDilHaiMushkil/NNP)
# (ORGANIZATION PM/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION PM/NNP)
# (GPE Hinterland/NNP)
# (ORGANIZATION IndiaKaDil/NNP)
# (ORGANIZATION SupremeCourt/NNP)
# (GPE Hinterland/NNP)
# (ORGANIZATION IndiaKaDil/NNP)
# (ORGANIZATION JanKiBaat/NNP)
# (ORGANIZATION DEMONETIZATION/NNP)
# (GPE Hinterland/NNP)
# (ORGANIZATION IndiaKaDil/NNP)
# (ORGANIZATION PareshRawal/NNP)
# (ORGANIZATION AccheDin/NNP)
# (GPE Kishtwar/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION MUDRA/NNP)
# (ORGANIZATION PM/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (GPE Kishtwar/NNP)
# (GPE Kishtwar/NNP)
# (GPE India/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION LarrySummers/NNP)
# (GPE India/NNP)
# (ORGANIZATION Mutilation/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION Bypolls/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION SAD/NNP)
# (ORGANIZATION NewIndianXpress/NN)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION ATMs/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION MUDRA/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION PM/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION Demonetization/NNP)
# (ORGANIZATION BREAKING/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION MUDRA/NNP)
# (ORGANIZATION CREDAI/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION RatanTata/NNP)
# (ORGANIZATION PM/NNP Narendra/NNP Modi/NNP)
# (ORGANIZATION MalikAshok/NNP)
# (ORGANIZATION PM/NNP Modi/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION HinduRajyam/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION SamajwadiParty/NNP)
# (ORGANIZATION Jaya/NNP Bachchan/NNP)
# (ORGANIZATION TMC/NNP)
# (ORGANIZATION Jantar/NNP Mantar/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION BREAKING/NNP)
# (ORGANIZATION NEWS/NNP)
# (GPE Kishtwar/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Kishtwar/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION Jaya/NNP Bachchan/NNP)
# (ORGANIZATION AAP/NNP)
# (ORGANIZATION TMC/NNP)
# (ORGANIZATION Jantar/NNP Mantar/NNP)
# (ORGANIZATION MUDRA/NNP)
# (ORGANIZATION Bypolls/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION RatanTata/NNP)
# (ORGANIZATION PM/NNP Narendra/NNP Modi/NNP)
# (GPE Kishtwar/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION MUDRA/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION RBI/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION LS/NNP)
# (ORGANIZATION BJP/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION Sir/NNP)
# (GPE UP/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION PM/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION PM/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION VishalDhanWale/NNP)
# (ORGANIZATION VishalJanSabha/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION LS/NNP)
# (ORGANIZATION BJP/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION LS/NNP)
# (ORGANIZATION BJP/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (GPE News24/NNP)
# (GPE Kishtwar/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (ORGANIZATION RBI/NNP)
# (ORGANIZATION RBIGov/NNP)
# (ORGANIZATION UrjitPatel/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION MobileApp/NNP)
# (ORGANIZATION CIOL/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION BSP/NNP)
# (ORGANIZATION PM/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION INC/NNP)
# (GPE Kishtwar/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION Narendra/NNP Modi/NNP App/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (ORGANIZATION Ultimate/NNP Weapon/NNP)
# (GPE Black/NNP)
# (ORGANIZATION IndiaFactsOrg/NNP)
# (ORGANIZATION Ultimate/NNP Weapon/NNP)
# (GPE Black/NNP)
# (GPE Watch/NN)
# (ORGANIZATION AeDilHaiMushkil/NNP)
# (ORGANIZATION BJP/NNP)
# (ORGANIZATION Ultimate/NNP Weapon/NNP)
# (GPE Black/NNP)
# (GPE Watch/NN)
# (ORGANIZATION AeDilHaiMushkil/NNP)
# (ORGANIZATION Ultimate/NNP Weapon/NNP)
# (GPE Black/NNP)
# (ORGANIZATION IndiaFactsOrg/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION CorruptionCle/NNP)
# (ORGANIZATION Ultimate/NNP Weapon/NNP)
# (GPE Black/NNP)
# (ORGANIZATION CorruptionCle/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION CorruptionCle/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION Ultimate/NNP Weapon/NNP)
# (GPE Black/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION ATMs/NNP)
# (ORGANIZATION PM/NNP)
# (GPE Delhi/NNP)
# (ORGANIZATION BQI/NNP)
# (ORGANIZATION ArvindKejriwal/NNP)
# (ORGANIZATION VishalJanSabha/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (ORGANIZATION PM/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION CREDAI/NNP)
# (ORGANIZATION Mashable/NNP)
# (GPE India/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION CREDAI/NNP)
# (ORGANIZATION NortheastIndia/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION Cashless/NNP)
# (ORGANIZATION DigitalIndia/NNP)
# (ORGANIZATION GoCashless/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (GPE Kishtwar/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION Opposition/NNP)
# (ORGANIZATION Parliame/NN)
# (ORGANIZATION PM/NNP)
# (GPE Band/NNP)
# (ORGANIZATION PMModi/NNP Take/NNP Part/NNP)
# (GPE Survey/NNP)
# (ORGANIZATION NMApp/NNP)
# (ORGANIZATION Part/NNP)
# (ORGANIZATION Nation/NNP)
# (GPE India/NNP)
# (ORGANIZATION UNESCO/NNP)
# (GPE India/NNP)
# (GPE Huge/JJ)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Digital/NNP)
# (GPE Massive/JJ)
# (GPE Indians/NNPS)
# (GPE Kishtwar/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Narendra/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION BJP4India/NNP)
# (GPE India/NNP)
# (GPE Indians/NNPS)
# (GPE Kishtwar/NNP)
# (ORGANIZATION PM/NNP)
# (GPE Wow/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION Entrepreneural/JJ Abilities/NNPS)
# (ORGANIZATION DigitalIndia/NNP)
# (ORGANIZATION CashlessSociety/NNP)
# (GPE India/NNP)
# (ORGANIZATION AK/NNP Pappu/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (GPE Gujarat/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION PM/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION BharatBandh/NNP)
# (ORGANIZATION November28th/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION BharatBandh/NNP)
# (ORGANIZATION November28th/NNP)
# (ORGANIZATION Opposition/NNP)
# (ORGANIZATION Parliame/NN)
# (ORGANIZATION Compliance/NN)
# (ORGANIZATION Round/NNP Table/NNP)
# (GPE Long/NNP)
# (GPE Kishtwar/NNP)
# (GPE India/NNP)
# (GPE India/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION Demonetization/NNP Citizens/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION ATM/NNP)
# (GPE Bengaluru/NNP)
# (ORGANIZATION BankRobbery/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION BeingReva/NNP No/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Kishtwar/NNP)
# (GPE Kishtwar/NNP)
# (GPE Kishtwar/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION YSRCP/NN Chief/NNP)
# (ORGANIZATION YSJagan/NNP)
# (ORGANIZATION NCBN/NNP)
# (ORGANIZATION PM/NNP)
# (GPE Long/NNP)
# (GPE Indian/NNP)
# (ORGANIZATION GDP/NNP)
# (GPE Kishtwar/NNP)
# (GPE Kishtwar/NNP)
# (GPE Kishtwar/NNP)
# (GPE Gujarat/NNP)
# (GPE Kishtwar/NNP)
# (GPE Wholesale/JJ)
# (GPE Hotels/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION YSRCP/NN Chief/NNP)
# (ORGANIZATION YSJagan/NNP)
# (ORGANIZATION NCBN/NNP)
# (GPE Antilia/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (GPE Kishtwar/NNP)
# (GPE Long/NNP)
# (GPE Indian/NNP)
# (ORGANIZATION GDP/NNP)
# (ORGANIZATION BWBusinessworld/NNP)
# (GPE Arjind/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION ATMs/NNP)
# (ORGANIZATION LOC/NNP)
# (ORGANIZATION PM/NNP)
# (GPE Street/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION Bypolls/NNP)
# (GPE Modi/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION ATMs/NNP)
# (GPE Ambani/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION LOT/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION PM/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION LOC/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION CNNnews18/NNP For/IN)
# (ORGANIZATION ShardaChitFund/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION PM/NNP)
# (GPE YouTube/NNP)
# (ORGANIZATION ACTIVITY/NNP)
# (ORGANIZATION DEMONETIZATION/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION LOT/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION JanKiBaat/NNP)
# (ORGANIZATION DEMONETIZATION/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION PM/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION Vallagers/NNS)
# (ORGANIZATION Villagers/NNP)
# (ORGANIZATION NDTV/NNP)
# (ORGANIZATION BlackMoney/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION Opposition/NNP)
# (ORGANIZATION Parliame/NN)
# (GPE Kishtwar/NNP)
# (GPE India/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION KashmirUnrest/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION LS/NNP)
# (ORGANIZATION BJP/NNP)
# (ORGANIZATION DeMonetization/NNP)
# (ORGANIZATION CorruptionFreeIndia/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION PM/NNP)
# (GPE Kishtwar/NNP)
# (GPE Kishtwar/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION NitishKumar/NNP)
# (ORGANIZATION PMModi/NNP)
# (ORGANIZATION blackMoneycleanup/NN)
# (ORGANIZATION Opposition/NNP)
# (ORGANIZATION Parliame/NN)
# (ORGANIZATION PM/NNP)
# (GPE Kishtwar/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION PM/NNP)
# (ORGANIZATION DeMonetization/NNP)
# ...
# (ORGANIZATION DONATE/NNP)
# (ORGANIZATION YOUTUBE/NNP)
# (GPE India/NNP)
# (ORGANIZATION Index/NNP)
# (ORGANIZATION Industrial/NNP)
# (ORGANIZATION CPI/NNP)
# (ORGANIZATION Consumer/NNP)
# (ORGANIZATION Index/NNP)
# (ORGANIZATION Industrial/NNP)
# (ORGANIZATION CPI/NNP)
# (ORGANIZATION Consumer/NNP)
# (ORGANIZATION Index/NNP)
# (ORGANIZATION Industrial/NNP)
# (ORGANIZATION CPI/NNP)
# (ORGANIZATION Consumer/NNP)
# (ORGANIZATION Index/NNP)
# (ORGANIZATION Industrial/NNP)
# (ORGANIZATION CPI/NNP)
# (ORGANIZATION Consumer/NNP)
# (ORGANIZATION Index/NNP)
# (ORGANIZATION Industrial/NNP)
# (ORGANIZATION CPI/NNP)
# (ORGANIZATION Consumer/NNP)
# (ORGANIZATION Index/NNP)
# (ORGANIZATION Industrial/NNP)
# (ORGANIZATION CPI/NNP)
# (ORGANIZATION Consumer/NNP)
# (ORGANIZATION Index/NNP)
# (ORGANIZATION Industrial/NNP)
# (ORGANIZATION CPI/NNP)
# (ORGANIZATION Consumer/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION Index/NNP)
# (ORGANIZATION Industrial/NNP)
# (ORGANIZATION CPI/NNP)
# (ORGANIZATION Consumer/NNP)
# (ORGANIZATION Index/NNP)
# (ORGANIZATION Industrial/NNP)
# (ORGANIZATION CPI/NNP)
# (ORGANIZATION Consumer/NNP)
# (ORGANIZATION Index/NNP)
# (ORGANIZATION Industrial/NNP)
# (ORGANIZATION CPI/NNP)
# (ORGANIZATION Consumer/NNP)
# (ORGANIZATION Index/NNP)
# (ORGANIZATION Industrial/NNP)
# (ORGANIZATION CPI/NNP)
# (ORGANIZATION Consumer/NNP)
# (ORGANIZATION Index/NNP)
# (ORGANIZATION Industrial/NNP)
# (ORGANIZATION CPI/NNP)
# (ORGANIZATION Consumer/NNP)
# (ORGANIZATION Index/NNP)
# (ORGANIZATION Industrial/NNP)
# (ORGANIZATION CPI/NNP)
# (ORGANIZATION Consumer/NNP)
# (ORGANIZATION Index/NNP)
# (ORGANIZATION Industrial/NNP)
# (ORGANIZATION CPI/NNP)
# (ORGANIZATION Consumer/NNP)
# (ORGANIZATION Index/NNP)
# (ORGANIZATION Industrial/NNP)
# (ORGANIZATION CPI/NNP)
# (ORGANIZATION Consumer/NNP)
# (ORGANIZATION Index/NNP)
# (ORGANIZATION Industrial/NNP)
# (ORGANIZATION CPI/NNP)
# (ORGANIZATION Consumer/NNP)
# (ORGANIZATION Index/NNP)
# (ORGANIZATION Industrial/NNP)
# (ORGANIZATION CPI/NNP)
# (ORGANIZATION Consumer/NNP)
# (ORGANIZATION Index/NNP)
# (ORGANIZATION Industrial/NNP)
# (ORGANIZATION CPI/NNP)
# (ORGANIZATION Consumer/NNP)
# (ORGANIZATION Index/NNP)
# (ORGANIZATION Industrial/NNP)
# (ORGANIZATION CPI/NNP)
# (ORGANIZATION Consumer/NNP)
# (ORGANIZATION Index/NNP)
# (ORGANIZATION Industrial/NNP)
# (ORGANIZATION CPI/NNP)
# (ORGANIZATION Consumer/NNP)
# (ORGANIZATION Loot/NNP Helped/NNP)
# (ORGANIZATION MLA/NNP Shopping/NNP)
# (ORGANIZATION KilaFateh/NNP)
# (ORGANIZATION Index/NNP)
# (ORGANIZATION Industrial/NNP)
# (ORGANIZATION CPI/NNP)
# (ORGANIZATION Consumer/NNP Pri/NNP)
# (ORGANIZATION Index/NNP)
# (ORGANIZATION Industrial/NNP)
# (ORGANIZATION CPI/NNP)
# (ORGANIZATION Consumer/NNP)
# (ORGANIZATION Index/NNP)
# (ORGANIZATION Industrial/NNP)
# (ORGANIZATION CPI/NNP)
# (ORGANIZATION Consumer/NNP Pri/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION Index/NNP)
# (ORGANIZATION Industrial/NNP)
# (ORGANIZATION CPI/NNP)
# (ORGANIZATION Consumer/NNP Pric/NNP)
# (GPE Banking/NNP)
# (ORGANIZATION Gurumurthy/NNP)
# (GPE Chennai/NNP)
# (ORGANIZATION YouTube/NN)
# (ORGANIZATION Demonetization/NNP Scheme/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION Loot/NNP Helped/NNP)
# (ORGANIZATION MLA/NNP Shopping/NNP)
# (ORGANIZATION KilaFateh/NNP)
# (ORGANIZATION Loot/NNP Helped/NNP)
# (ORGANIZATION MLA/NNP Shopping/NNP)
# (ORGANIZATION KilaFateh/NNP)
# (ORGANIZATION ShivAroor/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION Loot/NNP Helped/NNP)
# (ORGANIZATION MLA/NNP Shopping/NNP)
# (ORGANIZATION KilaFateh/NNP)
# (ORGANIZATION YouTube/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE India/NNP)
# (ORGANIZATION OOTT/NNP)
# (ORGANIZATION CNBC_Awaaz/NNP)
# (ORGANIZATION anilsinghviCNBC/NN)
# (ORGANIZATION WWII/NNP Hawaiian/NNP)
# (GPE Japan/NNP)
# (GPE Hawaii/NNP)
# (ORGANIZATION Demonetization/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION FinMinIndia/NNP Sir/NNP)
# (ORGANIZATION ATms/NNP)
# (GPE Indian/JJ)
# (GPE Indian/JJ)
# (GPE Indian/JJ)
# (ORGANIZATION YouTube/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION ATMs/NNP)
# (ORGANIZATION IncredibleIndia/NNP)
# (ORGANIZATION Demonetization/NNP)
# (ORGANIZATION MMS/NNP)
# (ORGANIZATION GreatGameIndia/NNP)
# (GPE GreatGameIndia/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Indian/JJ)
# (GPE Indian/JJ)
# (ORGANIZATION HRDMinistry/NNP)
# (ORGANIZATION ZeeNews/NNP)
# (GPE India/NNP)
# (ORGANIZATION Travelers/NNPS)
# (ORGANIZATION Bhattacharya/NNP)
# (GPE India/NNP)
# (GPE India/NNP)
# (ORGANIZATION Congress/NNP)
# (ORGANIZATION AAP/NNP)
# (ORGANIZATION Surgical/NNP Strike/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Indian/JJ)
# (GPE Vemula/NNP)
# (ORGANIZATION JNU/NNP)
# (ORGANIZATION SurgicalStrike/NNP)
# (GPE India/NNP)
# (ORGANIZATION NOT/NNP)
# (ORGANIZATION MUST/NNP)
# (GPE Industry/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Vemula/NNP)
# (ORGANIZATION JNU/NNP)
# (ORGANIZATION SurgicalStrike/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION WWII/NNP Hawaiian/NNP)
# (GPE Japan/NNP)
# (GPE Hawaii/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION Loot/NNP Helped/NNP)
# (ORGANIZATION MLA/NNP Shopping/NNP)
# (ORGANIZATION KilaFateh/NNP)
# (GPE Vemula/NNP)
# (ORGANIZATION JNU/NNP)
# (ORGANIZATION SurgicalStrike/NNP)
# (ORGANIZATION ExSecular/NNP)
# (GPE WP/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION DEMONETIZATION/NNP)
# (ORGANIZATION Producer/NNP Shansha/NNP Modi/NNP)
# (ORGANIZATION Loot/NNP Helped/NNP)
# (ORGANIZATION MLA/NNP Shopping/NNP)
# (ORGANIZATION KilaFateh/NNP)
# (ORGANIZATION IncrementPremierLeague/NNP)
# (GPE Vemula/NNP)
# (ORGANIZATION JNU/NNP)
# (ORGANIZATION SurgicalStrike/NNP)
# (GPE Vemula/NNP)
# (ORGANIZATION JNU/NNP)
# (ORGANIZATION SurgicalStrike/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION KushTrance/NNP)
# (ORGANIZATION PrisonPlanet/NNP Also/RB)
# (GPE Vemula/NNP)
# (ORGANIZATION JNU/NNP)
# (ORGANIZATION SurgicalStrike/NNP)
# (ORGANIZATION Loot/NNP Helped/NNP)
# (ORGANIZATION MLA/NNP Shopping/NNP)
# (ORGANIZATION KilaFateh/NNP)
# (ORGANIZATION HRDMinistry/NNP)
# (ORGANIZATION ZeeNews/NNP)
# (ORGANIZATION Demonetization/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE India/NNP)
# (ORGANIZATION ATMs/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION Loot/NNP Helped/NNP)
# (ORGANIZATION MLA/NNP Shopping/NNP)
# (ORGANIZATION KilaFateh/NNP)
# (ORGANIZATION Loot/NNP Helped/NNP)
# (ORGANIZATION MLA/NNP Shopping/NNP)
# (ORGANIZATION KilaFateh/NNP)
# (GPE India/NNP)
# (ORGANIZATION AdityaRajKaul/NNP)
# (ORGANIZATION Demonetization/NNP)
# (ORGANIZATION Real/JJ Estate/NNP)
# (GPE Jobs/NNP)
# (ORGANIZATION Gurumurthy/NNP)
# (GPE Chennai/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION Demonetization/NNP)
# (ORGANIZATION IncrementPremierLeague/NNP)
# (ORGANIZATION Demonetization/NNP)
# (ORGANIZATION IncrementPremierLeague/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION Demonetization/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION ShashiTharoor/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Quick/NNP)
# (ORGANIZATION DTH/NNP)
# (ORGANIZATION Demonetization/NNP)
# (ORGANIZATION IncrementPremierLeague/NNP)
# (ORGANIZATION Demonetization/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION Loot/NNP Helped/NNP)
# (ORGANIZATION MLA/NNP Shopping/NNP)
# (ORGANIZATION KilaFateh/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION ShashiTharoor/NNP Sir/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Word/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION IncrementPremierLeague/NNP)
# (ORGANIZATION ArvindKejriwal/NNP)
# (GPE ATMs/NNP)
# (ORGANIZATION ATMsDRY/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION ShashiTharoor/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION ShashiTharoor/NNP Sir/NNP)
# (ORGANIZATION ShashiTharoor/NNP Sir/NNP)
# (ORGANIZATION EconomicTimes/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION IncrementPremierLeague/NNP)
# (ORGANIZATION IncrementPremierLeague/NNP)
# (ORGANIZATION IncrementPremierLeague/NNP)
# (ORGANIZATION IncrementPremierLeague/NNP)
# (ORGANIZATION IncrementPremierLeague/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION BSIII/NNP)
# (GPE India/NNP)
# (ORGANIZATION BSIII/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION ShashiTharoor/NNP Sir/NNP)
# (ORGANIZATION Digital/NNP Payments/NNP)
# (ORGANIZATION Digital/NNP Ec/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION Demonetization/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION NRI/NNP)
# (ORGANIZATION RBI/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION ShashiTharoor/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION BruvPeace/NNP Closer/NNP)
# (ORGANIZATION USA/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION IncrementPremierLeague/NNP)
# (ORGANIZATION Demonetization/NNP)
# (GPE Monthly/JJ)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION salonishuklaET/NN India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION salonishuklaET/NN India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION salonishuklaET/NN Demonetization/NNP)
# (GPE Indian/JJ)
# (ORGANIZATION ShashiTharoor/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION ShashiTharoor/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION BruvPeace/NNP Closer/NNP)
# (ORGANIZATION USA/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (GPE Kerala/NNP)
# (GPE India/NNP)
# (ORGANIZATION ATMs/NNP)
# (ORGANIZATION BJP/NNP)
# (ORGANIZATION GDP/NNP)
# (ORGANIZATION ATMs/NNP)
# (ORGANIZATION VedantIndia/NNP)
# (ORGANIZATION Demonetization/NNP)
# (ORGANIZATION No/NNP)
# (GPE Went/NN)
# (ORGANIZATION FM/NNP)
# (ORGANIZATION Loot/NNP Helped/NNP)
# (ORGANIZATION MLA/NNP Shopping/NNP)
# (ORGANIZATION KilaFateh/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION AdSenseGate/NNP)
# (ORGANIZATION PRnightmare/NNP)
# (ORGANIZATION Eliminate/NNP Advertiser/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION ATMs/NNP)
# (ORGANIZATION Demonetization/NNP Daily/NNP)
# (ORGANIZATION Amor_y_Rabia/NNP)
# (GPE Headline/NNP)
# (ORGANIZATION ATMs/NNP)
# (ORGANIZATION ATMs/NNP)
# (ORGANIZATION Demonetization/NNP)
# (ORGANIZATION Real/JJ Estate/NNP)
# (ORGANIZATION Demonetization/NNP)
# (ORGANIZATION IncrementPremierLeague/NNP)
# (ORGANIZATION Loot/NNP Helped/NNP)
# (ORGANIZATION MLA/NNP Shopping/NNP)
# (ORGANIZATION KilaFateh/NNP)
# (ORGANIZATION ATMs/NNP)
# (ORGANIZATION AdSenseGate/NNP)
# (ORGANIZATION PRnightmare/NNP)
# (ORGANIZATION Eliminate/NNP Advertiser/NNP)
# (ORGANIZATION SaveYouTube/NNP)
# (ORGANIZATION John_Miller_GLR/NNP)
# (ORGANIZATION Demonetization/NNP)
# (ORGANIZATION IncrementPremierLeague/NNP)
# (ORGANIZATION John_Miller_GLR/NNP)
# (ORGANIZATION Demonetization/NNP)
# (ORGANIZATION IncrementPremierLeague/NNP)
# (ORGANIZATION KarmaBites/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION AdsenseGate/NNP)
# (ORGANIZATION PRnightmare/NNP)
# (ORGANIZATION ATMs/NNP)
# (ORGANIZATION FY/NNP)
# (GPE Please/NNP)
# (GPE Dear/NNP)
# (ORGANIZATION Demonetization/NNP)
# (GPE Macro/NNP)
# (ORGANIZATION Demonetization/NNP)
# (ORGANIZATION Real/JJ Estate/NNP)
# (GPE India/NNP)
# (ORGANIZATION Loot/NNP Helped/NNP)
# (ORGANIZATION MLA/NNP Shopping/NNP)
# (ORGANIZATION KilaFateh/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION LZs/NNP)
# (ORGANIZATION RSS/NNP)
# (ORGANIZATION BJP/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION BJP/NNP)
# (ORGANIZATION MLA/NNP Bhawani/NNP Singh/NNP Rajawat/NNP)
# (ORGANIZATION Demonetization/NNP Move/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION AtomPower/NNP)
# (GPE Rs/NNP)
# (ORGANIZATION NDTV/NNP)
# (ORGANIZATION Democidal/NNP)
# (GPE India/NNP)
# (GPE Funny/NNP)
# (GPE India/NNP)
# (ORGANIZATION Loot/NNP Helped/NNP)
# (ORGANIZATION MLA/NNP Shopping/NNP)
# (ORGANIZATION KilaFateh/NNP)
# (GPE Bhiwandi/NNP)
# (GPE July/NNP)
# (ORGANIZATION RBI/NNP)
# (ORGANIZATION ATMs/NNP)
# (ORGANIZATION ATMs/NNP)
# (ORGANIZATION Loot/NNP Helped/NNP)
# (ORGANIZATION MLA/NNP Shopping/NNP)
# (ORGANIZATION KilaFateh/NNP)
# (ORGANIZATION ATMs/NNP)
# (ORGANIZATION ATMs/NNP)
# (ORGANIZATION YouTube/NNP)
# (GPE Look/NN)
# (ORGANIZATION ATMs/NNP)
# (GPE ATMs/NNP)
# (ORGANIZATION Demonetization/NNP)
# (GPE Economy/NNP)
# (ORGANIZATION Investment/NNP)
# (ORGANIZATION SIP/NNP)
# (ORGANIZATION RBI/NNP)
# (GPE Christmas2016/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION RSMMA/NNP)
# (ORGANIZATION Demonetization/NNP)
# (GPE India/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION YouTube/NN)
# (GPE India/NNP)
# (ORGANIZATION RBI/NNP)
# (ORGANIZATION Demonetization/NNP)
# (ORGANIZATION Demonetization/NNP)
# (ORGANIZATION YouTube/NNP)
# (GPE India/NNP)
# (ORGANIZATION Demonetization/NNP)
# (ORGANIZATION Demonetization/NNP)
# (ORGANIZATION RenukaJain6/NNP)
# (GPE Hypothetical/NNP)
# (GPE India/NNP)
# (ORGANIZATION LongViewer/NNP)
# (ORGANIZATION TSLA/NNP)
# (GPE India/NNP)
# (GPE India/NNP)
# (GPE India/NNP)
# (ORGANIZATION _N33R4J_/NNP)
# (ORGANIZATION Loot/NNP Helped/NNP)
# (ORGANIZATION MLA/NNP Shopping/NNP)
# (ORGANIZATION KilaFateh/NNP)
# (ORGANIZATION htTweets/NNS)
# (ORGANIZATION MahuaVenkatesh/NNP)
# (ORGANIZATION timeMust/NN)
# (ORGANIZATION weNot/NN)
# (GPE YouTube/NNP)
# (GPE Easy/JJ)
# (GPE India/NNP)
# (GPE India/NNP)
# (ORGANIZATION MUST/NNP)
# (GPE READ/NNP)
# (GPE Industry/NNP)
# (GPE United/NNP)
# (ORGANIZATION YouTube/NNP)
# (GPE Wow/NNP)
# (ORGANIZATION YouTube/NNP)
# (GPE Indian/JJ)
# (GPE India/NNP)
# (ORGANIZATION ArvindKejriwal/NNP)
# (ORGANIZATION EVM/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION Loot/NNP Helped/NNP)
# (ORGANIZATION MLA/NNP Shopping/NNP)
# (ORGANIZATION KilaFateh/NNP)
# (GPE India/NNP)
# (ORGANIZATION Demonetization/NNP Daily/NNP)
# (ORGANIZATION VallumConnect/NNP)
# (GPE Currency/NN)
# (ORGANIZATION PuthanPanam/NNP)
# (ORGANIZATION PuthanPanamReview/NNP)
# (ORGANIZATION Gupta/NNP)
# (GPE India/NNP)
# (GPE India/NNP)
# (ORGANIZATION YouTube/NNP)
# (GPE Chicago/NNP)
# (ORGANIZATION ArvindKejriwal/NNP)
# (ORGANIZATION EVM/NNP)
# (GPE India/NNP)
# (GPE India/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION Demonetization/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION GST/NNP)
# (GPE India/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION OCI/NNP)
# (GPE India/NNP)
# (ORGANIZATION
#   Demonetization/NNP
#   Baseless/NNP
#   As/IN
#   Young/NNP
#   Turks/NNP
#   Get/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION
#   Demonetization/NNP
#   Baseless/NNP
#   As/IN
#   Young/NNP
#   Turks/NNP
#   Get/NNP)
# (ORGANIZATION YouTube/NNP)
# (GPE Oakland/NNP)
# (ORGANIZATION YouTube/NNP)
# (GPE Oakland/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION YouTube/NNP)
# (GPE India/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION YouTube/NNP)
# (GPE India/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION MarkDice/NNP And/CC)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION MFs/NNP)
# (GPE Indian/JJ)
# (ORGANIZATION Loot/NNP Helped/NNP)
# (ORGANIZATION MLA/NNP Shopping/NNP)
# (ORGANIZATION KilaFateh/NNP)
# (ORGANIZATION BTW/NNP)
# (ORGANIZATION EVM/NNP)
# (GPE Venezuela/NNP)
# (ORGANIZATION Gurumurthy/NNP)
# (GPE Chennai/NNP)
# (ORGANIZATION GOI/NNP)
# (ORGANIZATION Loot/NNP Helped/NNP)
# (ORGANIZATION MLA/NNP Shopping/NNP)
# (ORGANIZATION KilaFateh/NNP)
# (ORGANIZATION Loot/NNP Helped/NNP)
# (ORGANIZATION MLA/NNP Shopping/NNP)
# (ORGANIZATION KilaFateh/NNP)
# (ORGANIZATION i_AjayGopi/NN Agricultre/NNP)
# (GPE India/NNP)
# (ORGANIZATION ATM/NNP)
# (ORGANIZATION PhilipDeFranco/NNP)
# (ORGANIZATION YouTube/NNP)
# (ORGANIZATION PRnightmare/NNP)
# (ORGANIZATION AdsenseGate/NNP)
# (ORGANIZATION Mind_it/NNP)
# (ORGANIZATION YouTube/NNP)
# (GPE India/NNP)
# (ORGANIZATION MartinRavallion/NNP)
# (GPE India/NNP)
# (ORGANIZATION BJP/NNP)
# (ORGANIZATION CIA/NNP)
# (ORGANIZATION CCTV/NNP)
# (ORGANIZATION EVM/NNP)
# (ORGANIZATION VVPAT/NNP)
# (ORGANIZATION JNU/NNP)
# (ORGANIZATION BJP/NNP)
# (ORGANIZATION CIA/NNP)
# (ORGANIZATION CCTV/NNP)
# (ORGANIZATION EVM/NNP)
# (ORGANIZATION VVPAT/NNP)
# (ORGANIZATION JNU/NNP)

# %%
## Sentiment analysis 
from textblob import TextBlob
TextBlob("many people hate policy changes such as Demonitization").sentiment
# Out:
# Sentiment(polarity=-0.10000000000000002, subjectivity=0.6333333333333333)

# %%
TextBlob("Indians are happy after from Demonitization").sentiment
# Out:
# Sentiment(polarity=0.8, subjectivity=1.0)

# %%
## Topic Modelling 
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np 

def generate_topic_models(text):
    cvectorizer = CountVectorizer(min_df=4, max_features=2000)
    cvz = cvectorizer.fit_transform(text)

    lda_model = LatentDirichletAllocation(n_components=10, learning_method='online', max_iter=20, random_state=42)
    X_topics = lda_model.fit_transform(cvz)

    topic_word = lda_model.components_ 
    vocab = cvectorizer.get_feature_names()
    return topic_word, vocab 

n_top_words = 10
topic_word, vocab = generate_topic_models(tweets["cleaned"].values)
for i, topic_dist in enumerate(topic_word):
    topic_words = np.array(vocab)[np.argsort(topic_dist)][:-(n_top_words+1):-1]
    print ("Topic " + str(i+1) + ": " + " | ".join(topic_words) + "\n")
# Out:
# Topic 1: demonetization | people | rt | back | narendramodi | across | move | support | pm | nation
#
# Topic 2: demonetization | india | rt | rich | dear | implement | youtube | impact | running | narendramodi
#
# Topic 3: demonetization | rt | impact | shortage | bypolls | man | bjp | https | parliament | shashitharoor
#
# Topic 4: modi | pm | demonetization | rt | narendra | find | evanspiegel | urautelaforever | cash | atms
#
# Topic 5: demonetization | bank | rt | rs | terrorists | jampk | lakh | since | thats | third
#
# Topic 6: actually | rt | demonetization | money | whether | still | goes | drkumarvishwas | mru092du093eu0935u0941u0915 | oscar
#
# Topic 7: demonetization | rt | due | good | says | today | india | indias | yogi | like
#
# Topic 8: demonetization | rt | adityanath | blackmoney | makes | reflected | transparent | politicsits | piyushgoyaloffc | results
#
# Topic 9: demonetization | rt | modis | govt | effect | first | via | historically | ujjwala | neem
#
# Topic 10: demonetization | rt | amp | question | paytm | pm | poor | full | clearly | rssurjewala

# %% [markdown]
# ## Ideas for information linkings
#
# - Descriptive Stats
#   example : which are the top mentioned persons, which locations are the ones with high negative sentiments etc.
# - TimeSeries Insights
#   example : how does the information changes over time
# - What are the action items
# - Use this information in Recommendation Engines
# - Use this information in Machine Learning Models
# - Use this information to create knowledge banks
